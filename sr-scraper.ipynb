# %% [markdown]
# Sports Reference Scraper

# %%
# installing necessary packages. uncomment if you need to use any


# %pip install scrapy
# %pip install crochet

# %%
import scrapy
import numpy as np
import pandas as pd

# %%
import requests
from scrapy import Selector

url = "https://www.sports-reference.com/cbb/schools/"
html = requests.get(url).text
sel = Selector(text=html)

# 1. Find the wrapper
wrapper = sel.css('#all_NCAAW_schools')

# 2. Try to get the comment inside
comment = wrapper.xpath('comment()').get()

if comment:
    # It was hidden! Clean it.
    clean_html = comment.replace('', '')
    table_sel = Selector(text=clean_html)
    print("Found table in comments. Unwrapping...")
else:
    # It wasn't hidden! Use the wrapper directly.
    table_sel = wrapper
    print("Table was not commented. Reading directly...")

# 3. Extract the links
links_list = [
    f"https://www.sports-reference.com{link}" 
    for link in table_sel.css('td[data-stat="school_name"] a::attr(href)').getall()
]

print(f"Successfully found {len(links_list)} links.")
# Out:
# Table was not commented. Reading directly...
# Successfully found 380 links.

# %%
links_list
# Out:
# ['https://www.sports-reference.com/cbb/schools/abilene-christian/women/',
#  'https://www.sports-reference.com/cbb/schools/air-force/women/',
#  'https://www.sports-reference.com/cbb/schools/akron/women/',
#  'https://www.sports-reference.com/cbb/schools/alabama/women/',
#  'https://www.sports-reference.com/cbb/schools/alabama-am/women/',
#  'https://www.sports-reference.com/cbb/schools/alabama-state/women/',
#  'https://www.sports-reference.com/cbb/schools/albany-ny/women/',
#  'https://www.sports-reference.com/cbb/schools/alcorn-state/women/',
#  'https://www.sports-reference.com/cbb/schools/american/women/',
#  'https://www.sports-reference.com/cbb/schools/appalachian-state/women/',
#  'https://www.sports-reference.com/cbb/schools/arizona/women/',
#  'https://www.sports-reference.com/cbb/schools/arizona-state/women/',
#  'https://www.sports-reference.com/cbb/schools/arkansas/women/',
#  'https://www.sports-reference.com/cbb/schools/arkansas-state/women/',
#  'https://www.sports-reference.com/cbb/schools/arkansas-pine-bluff/women/',
#  'https://www.sports-reference.com/cbb/schools/army/women/',
#  'https://www.sports-reference.com/cbb/schools/auburn/women/',
#  'https://www.sports-reference.com/cbb/schools/augusta-state/women/',
#  'https://www.sports-reference.com/cbb/schools/austin-peay/women/',
#  'https://www.sports-reference.com/cbb/schools/ball-state/women/',
#  'https://www.sports-reference.com/cbb/schools/baylor/women/',
#  'https://www.sports-reference.com/cbb/schools/bellarmine/women/',
#  'https://www.sports-reference.com/cbb/schools/belmont/women/',
#  'https://www.sports-reference.com/cbb/schools/bethune-cookman/women/',
#  'https://www.sports-reference.com/cbb/schools/binghamton/women/',
#  'https://www.sports-reference.com/cbb/schools/birmingham-southern/women/',
#  'https://www.sports-reference.com/cbb/schools/boise-state/women/',
#  'https://www.sports-reference.com/cbb/schools/boston-college/women/',
#  'https://www.sports-reference.com/cbb/schools/boston-university/women/',
#  'https://www.sports-reference.com/cbb/schools/bowling-green-state/women/',
#  'https://www.sports-reference.com/cbb/schools/bradley/women/',
#  'https://www.sports-reference.com/cbb/schools/brigham-young/women/',
#  'https://www.sports-reference.com/cbb/schools/brooklyn/women/',
#  'https://www.sports-reference.com/cbb/schools/brown/women/',
#  'https://www.sports-reference.com/cbb/schools/bryant/women/',
#  'https://www.sports-reference.com/cbb/schools/bucknell/women/',
#  'https://www.sports-reference.com/cbb/schools/buffalo/women/',
#  'https://www.sports-reference.com/cbb/schools/butler/women/',
#  'https://www.sports-reference.com/cbb/schools/cal-poly/women/',
#  'https://www.sports-reference.com/cbb/schools/cal-state-bakersfield/women/',
#  'https://www.sports-reference.com/cbb/schools/cal-state-fullerton/women/',
#  'https://www.sports-reference.com/cbb/schools/cal-state-northridge/women/',
#  'https://www.sports-reference.com/cbb/schools/california/women/',
#  'https://www.sports-reference.com/cbb/schools/california-baptist/women/',
#  'https://www.sports-reference.com/cbb/schools/campbell/women/',
#  'https://www.sports-reference.com/cbb/schools/canisius/women/',
#  'https://www.sports-reference.com/cbb/schools/centenary-la/women/',
#  'https://www.sports-reference.com/cbb/schools/central-arkansas/women/',
#  'https://www.sports-reference.com/cbb/schools/central-connecticut-state/women/',
#  'https://www.sports-reference.com/cbb/schools/central-michigan/women/',
#  'https://www.sports-reference.com/cbb/schools/charleston-southern/women/',
#  'https://www.sports-reference.com/cbb/schools/charlotte/women/',
#  'https://www.sports-reference.com/cbb/schools/chattanooga/women/',
#  'https://www.sports-reference.com/cbb/schools/cheyney/women/',
#  'https://www.sports-reference.com/cbb/schools/chicago-state/women/',
#  'https://www.sports-reference.com/cbb/schools/cincinnati/women/',
#  'https://www.sports-reference.com/cbb/schools/clemson/women/',
#  'https://www.sports-reference.com/cbb/schools/cleveland-state/women/',
#  'https://www.sports-reference.com/cbb/schools/coastal-carolina/women/',
#  'https://www.sports-reference.com/cbb/schools/colgate/women/',
#  'https://www.sports-reference.com/cbb/schools/college-of-charleston/women/',
#  'https://www.sports-reference.com/cbb/schools/colorado/women/',
#  'https://www.sports-reference.com/cbb/schools/colorado-state/women/',
#  'https://www.sports-reference.com/cbb/schools/columbia/women/',
#  'https://www.sports-reference.com/cbb/schools/connecticut/women/',
#  'https://www.sports-reference.com/cbb/schools/coppin-state/women/',
#  'https://www.sports-reference.com/cbb/schools/cornell/women/',
#  'https://www.sports-reference.com/cbb/schools/creighton/women/',
#  'https://www.sports-reference.com/cbb/schools/dartmouth/women/',
#  'https://www.sports-reference.com/cbb/schools/davidson/women/',
#  'https://www.sports-reference.com/cbb/schools/dayton/women/',
#  'https://www.sports-reference.com/cbb/schools/delaware/women/',
#  'https://www.sports-reference.com/cbb/schools/delaware-state/women/',
#  'https://www.sports-reference.com/cbb/schools/delta-state/women/',
#  'https://www.sports-reference.com/cbb/schools/denver/women/',
#  'https://www.sports-reference.com/cbb/schools/depaul/women/',
#  'https://www.sports-reference.com/cbb/schools/detroit-mercy/women/',
#  'https://www.sports-reference.com/cbb/schools/drake/women/',
#  'https://www.sports-reference.com/cbb/schools/drexel/women/',
#  'https://www.sports-reference.com/cbb/schools/duke/women/',
#  'https://www.sports-reference.com/cbb/schools/duquesne/women/',
#  'https://www.sports-reference.com/cbb/schools/east-carolina/women/',
#  'https://www.sports-reference.com/cbb/schools/east-tennessee-state/women/',
#  'https://www.sports-reference.com/cbb/schools/texas-am-commerce/women/',
#  'https://www.sports-reference.com/cbb/schools/eastern-illinois/women/',
#  'https://www.sports-reference.com/cbb/schools/eastern-kentucky/women/',
#  'https://www.sports-reference.com/cbb/schools/eastern-michigan/women/',
#  'https://www.sports-reference.com/cbb/schools/eastern-washington/women/',
#  'https://www.sports-reference.com/cbb/schools/elon/women/',
#  'https://www.sports-reference.com/cbb/schools/evansville/women/',
#  'https://www.sports-reference.com/cbb/schools/fairfield/women/',
#  'https://www.sports-reference.com/cbb/schools/fairleigh-dickinson/women/',
#  'https://www.sports-reference.com/cbb/schools/florida/women/',
#  'https://www.sports-reference.com/cbb/schools/florida-am/women/',
#  'https://www.sports-reference.com/cbb/schools/florida-atlantic/women/',
#  'https://www.sports-reference.com/cbb/schools/florida-gulf-coast/women/',
#  'https://www.sports-reference.com/cbb/schools/florida-international/women/',
#  'https://www.sports-reference.com/cbb/schools/florida-state/women/',
#  'https://www.sports-reference.com/cbb/schools/fordham/women/',
#  'https://www.sports-reference.com/cbb/schools/fresno-state/women/',
#  'https://www.sports-reference.com/cbb/schools/furman/women/',
#  'https://www.sports-reference.com/cbb/schools/gardner-webb/women/',
#  'https://www.sports-reference.com/cbb/schools/george-mason/women/',
#  'https://www.sports-reference.com/cbb/schools/george-washington/women/',
#  'https://www.sports-reference.com/cbb/schools/georgetown/women/',
#  'https://www.sports-reference.com/cbb/schools/georgia/women/',
#  'https://www.sports-reference.com/cbb/schools/georgia-southern/women/',
#  'https://www.sports-reference.com/cbb/schools/georgia-state/women/',
#  'https://www.sports-reference.com/cbb/schools/georgia-tech/women/',
#  'https://www.sports-reference.com/cbb/schools/gonzaga/women/',
#  'https://www.sports-reference.com/cbb/schools/grambling/women/',
#  'https://www.sports-reference.com/cbb/schools/grand-canyon/women/',
#  'https://www.sports-reference.com/cbb/schools/green-bay/women/',
#  'https://www.sports-reference.com/cbb/schools/hampton/women/',
#  'https://www.sports-reference.com/cbb/schools/hardin-simmons/women/',
#  'https://www.sports-reference.com/cbb/schools/hartford/women/',
#  'https://www.sports-reference.com/cbb/schools/harvard/women/',
#  'https://www.sports-reference.com/cbb/schools/hawaii/women/',
#  'https://www.sports-reference.com/cbb/schools/high-point/women/',
#  'https://www.sports-reference.com/cbb/schools/hofstra/women/',
#  'https://www.sports-reference.com/cbb/schools/holy-cross/women/',
#  'https://www.sports-reference.com/cbb/schools/houston/women/',
#  'https://www.sports-reference.com/cbb/schools/houston-baptist/women/',
#  'https://www.sports-reference.com/cbb/schools/howard/women/',
#  'https://www.sports-reference.com/cbb/schools/idaho/women/',
#  'https://www.sports-reference.com/cbb/schools/idaho-state/women/',
#  'https://www.sports-reference.com/cbb/schools/illinois/women/',
#  'https://www.sports-reference.com/cbb/schools/illinois-state/women/',
#  'https://www.sports-reference.com/cbb/schools/illinois-chicago/women/',
#  'https://www.sports-reference.com/cbb/schools/incarnate-word/women/',
#  'https://www.sports-reference.com/cbb/schools/indiana/women/',
#  'https://www.sports-reference.com/cbb/schools/indiana-state/women/',
#  'https://www.sports-reference.com/cbb/schools/iona/women/',
#  'https://www.sports-reference.com/cbb/schools/iowa/women/',
#  'https://www.sports-reference.com/cbb/schools/iowa-state/women/',
#  'https://www.sports-reference.com/cbb/schools/iupui/women/',
#  'https://www.sports-reference.com/cbb/schools/jackson-state/women/',
#  'https://www.sports-reference.com/cbb/schools/jacksonville/women/',
#  'https://www.sports-reference.com/cbb/schools/jacksonville-state/women/',
#  'https://www.sports-reference.com/cbb/schools/james-madison/women/',
#  'https://www.sports-reference.com/cbb/schools/kansas/women/',
#  'https://www.sports-reference.com/cbb/schools/missouri-kansas-city/women/',
#  'https://www.sports-reference.com/cbb/schools/kansas-state/women/',
#  'https://www.sports-reference.com/cbb/schools/kennesaw-state/women/',
#  'https://www.sports-reference.com/cbb/schools/kent-state/women/',
#  'https://www.sports-reference.com/cbb/schools/kentucky/women/',
#  'https://www.sports-reference.com/cbb/schools/la-salle/women/',
#  'https://www.sports-reference.com/cbb/schools/lafayette/women/',
#  'https://www.sports-reference.com/cbb/schools/lamar/women/',
#  'https://www.sports-reference.com/cbb/schools/le-moyne/women/',
#  'https://www.sports-reference.com/cbb/schools/lehigh/women/',
#  'https://www.sports-reference.com/cbb/schools/liberty/women/',
#  'https://www.sports-reference.com/cbb/schools/lindenwood/women/',
#  'https://www.sports-reference.com/cbb/schools/lipscomb/women/',
#  'https://www.sports-reference.com/cbb/schools/arkansas-little-rock/women/',
#  'https://www.sports-reference.com/cbb/schools/long-beach-state/women/',
#  'https://www.sports-reference.com/cbb/schools/long-island-university/women/',
#  'https://www.sports-reference.com/cbb/schools/longwood/women/',
#  'https://www.sports-reference.com/cbb/schools/louisiana-lafayette/women/',
#  'https://www.sports-reference.com/cbb/schools/louisiana-state/women/',
#  'https://www.sports-reference.com/cbb/schools/louisiana-tech/women/',
#  'https://www.sports-reference.com/cbb/schools/louisiana-monroe/women/',
#  'https://www.sports-reference.com/cbb/schools/louisville/women/',
#  'https://www.sports-reference.com/cbb/schools/loyola-il/women/',
#  'https://www.sports-reference.com/cbb/schools/loyola-md/women/',
#  'https://www.sports-reference.com/cbb/schools/loyola-marymount/women/',
#  'https://www.sports-reference.com/cbb/schools/maine/women/',
#  'https://www.sports-reference.com/cbb/schools/manhattan/women/',
#  'https://www.sports-reference.com/cbb/schools/marist/women/',
#  'https://www.sports-reference.com/cbb/schools/marquette/women/',
#  'https://www.sports-reference.com/cbb/schools/marshall/women/',
#  'https://www.sports-reference.com/cbb/schools/maryland/women/',
#  'https://www.sports-reference.com/cbb/schools/maryland-baltimore-county/women/',
#  'https://www.sports-reference.com/cbb/schools/maryland-eastern-shore/women/',
#  'https://www.sports-reference.com/cbb/schools/massachusetts/women/',
#  'https://www.sports-reference.com/cbb/schools/massachusetts-lowell/women/',
#  'https://www.sports-reference.com/cbb/schools/mcneese-state/women/',
#  'https://www.sports-reference.com/cbb/schools/memphis/women/',
#  'https://www.sports-reference.com/cbb/schools/mercer/women/',
#  'https://www.sports-reference.com/cbb/schools/mercyhurst/women/',
#  'https://www.sports-reference.com/cbb/schools/merrimack/women/',
#  'https://www.sports-reference.com/cbb/schools/miami-fl/women/',
#  'https://www.sports-reference.com/cbb/schools/miami-oh/women/',
#  'https://www.sports-reference.com/cbb/schools/michigan/women/',
#  'https://www.sports-reference.com/cbb/schools/michigan-state/women/',
#  'https://www.sports-reference.com/cbb/schools/middle-tennessee/women/',
#  'https://www.sports-reference.com/cbb/schools/milwaukee/women/',
#  'https://www.sports-reference.com/cbb/schools/minnesota/women/',
#  'https://www.sports-reference.com/cbb/schools/mississippi/women/',
#  'https://www.sports-reference.com/cbb/schools/mississippi-college/women/',
#  'https://www.sports-reference.com/cbb/schools/mississippi-state/women/',
#  'https://www.sports-reference.com/cbb/schools/mississippi-valley-state/women/',
#  'https://www.sports-reference.com/cbb/schools/missouri/women/',
#  'https://www.sports-reference.com/cbb/schools/missouri-state/women/',
#  'https://www.sports-reference.com/cbb/schools/monmouth/women/',
#  'https://www.sports-reference.com/cbb/schools/montana/women/',
#  'https://www.sports-reference.com/cbb/schools/montana-state/women/',
#  'https://www.sports-reference.com/cbb/schools/montclair-state/women/',
#  'https://www.sports-reference.com/cbb/schools/morehead-state/women/',
#  'https://www.sports-reference.com/cbb/schools/morgan-state/women/',
#  'https://www.sports-reference.com/cbb/schools/mount-st-marys/women/',
#  'https://www.sports-reference.com/cbb/schools/murray-state/women/',
#  'https://www.sports-reference.com/cbb/schools/navy/women/',
#  'https://www.sports-reference.com/cbb/schools/north-carolina-state/women/',
#  'https://www.sports-reference.com/cbb/schools/nebraska/women/',
#  'https://www.sports-reference.com/cbb/schools/nevada/women/',
#  'https://www.sports-reference.com/cbb/schools/nevada-las-vegas/women/',
#  'https://www.sports-reference.com/cbb/schools/new-hampshire/women/',
#  'https://www.sports-reference.com/cbb/schools/new-haven/women/',
#  'https://www.sports-reference.com/cbb/schools/new-mexico/women/',
#  'https://www.sports-reference.com/cbb/schools/new-mexico-state/women/',
#  'https://www.sports-reference.com/cbb/schools/new-orleans/women/',
#  'https://www.sports-reference.com/cbb/schools/niagara/women/',
#  'https://www.sports-reference.com/cbb/schools/nicholls-state/women/',
#  'https://www.sports-reference.com/cbb/schools/njit/women/',
#  'https://www.sports-reference.com/cbb/schools/norfolk-state/women/',
#  'https://www.sports-reference.com/cbb/schools/north-alabama/women/',
#  'https://www.sports-reference.com/cbb/schools/north-carolina/women/',
#  'https://www.sports-reference.com/cbb/schools/north-carolina-at/women/',
#  'https://www.sports-reference.com/cbb/schools/north-carolina-central/women/',
#  'https://www.sports-reference.com/cbb/schools/north-dakota/women/',
#  'https://www.sports-reference.com/cbb/schools/north-dakota-state/women/',
#  'https://www.sports-reference.com/cbb/schools/north-florida/women/',
#  'https://www.sports-reference.com/cbb/schools/north-texas/women/',
#  'https://www.sports-reference.com/cbb/schools/northeastern/women/',
#  'https://www.sports-reference.com/cbb/schools/northeastern-illinois/women/',
#  'https://www.sports-reference.com/cbb/schools/northern-arizona/women/',
#  'https://www.sports-reference.com/cbb/schools/northern-colorado/women/',
#  'https://www.sports-reference.com/cbb/schools/northern-illinois/women/',
#  'https://www.sports-reference.com/cbb/schools/northern-iowa/women/',
#  'https://www.sports-reference.com/cbb/schools/northern-kentucky/women/',
#  'https://www.sports-reference.com/cbb/schools/northwestern/women/',
#  'https://www.sports-reference.com/cbb/schools/northwestern-state/women/',
#  'https://www.sports-reference.com/cbb/schools/notre-dame/women/',
#  'https://www.sports-reference.com/cbb/schools/oakland/women/',
#  'https://www.sports-reference.com/cbb/schools/ohio/women/',
#  'https://www.sports-reference.com/cbb/schools/ohio-state/women/',
#  'https://www.sports-reference.com/cbb/schools/oklahoma/women/',
#  'https://www.sports-reference.com/cbb/schools/oklahoma-city/women/',
#  'https://www.sports-reference.com/cbb/schools/oklahoma-state/women/',
#  'https://www.sports-reference.com/cbb/schools/old-dominion/women/',
#  'https://www.sports-reference.com/cbb/schools/nebraska-omaha/women/',
#  'https://www.sports-reference.com/cbb/schools/oral-roberts/women/',
#  'https://www.sports-reference.com/cbb/schools/oregon/women/',
#  'https://www.sports-reference.com/cbb/schools/oregon-state/women/',
#  'https://www.sports-reference.com/cbb/schools/pacific/women/',
#  'https://www.sports-reference.com/cbb/schools/penn-state/women/',
#  'https://www.sports-reference.com/cbb/schools/pennsylvania/women/',
#  'https://www.sports-reference.com/cbb/schools/pepperdine/women/',
#  'https://www.sports-reference.com/cbb/schools/pittsburgh/women/',
#  'https://www.sports-reference.com/cbb/schools/portland/women/',
#  'https://www.sports-reference.com/cbb/schools/portland-state/women/',
#  'https://www.sports-reference.com/cbb/schools/prairie-view/women/',
#  'https://www.sports-reference.com/cbb/schools/presbyterian/women/',
#  'https://www.sports-reference.com/cbb/schools/princeton/women/',
#  'https://www.sports-reference.com/cbb/schools/providence/women/',
#  'https://www.sports-reference.com/cbb/schools/purdue/women/',
#  'https://www.sports-reference.com/cbb/schools/ipfw/women/',
#  'https://www.sports-reference.com/cbb/schools/queens-nc/women/',
#  'https://www.sports-reference.com/cbb/schools/queens-ny/women/',
#  'https://www.sports-reference.com/cbb/schools/quinnipiac/women/',
#  'https://www.sports-reference.com/cbb/schools/radford/women/',
#  'https://www.sports-reference.com/cbb/schools/rhode-island/women/',
#  'https://www.sports-reference.com/cbb/schools/rice/women/',
#  'https://www.sports-reference.com/cbb/schools/richmond/women/',
#  'https://www.sports-reference.com/cbb/schools/rider/women/',
#  'https://www.sports-reference.com/cbb/schools/robert-morris/women/',
#  'https://www.sports-reference.com/cbb/schools/rutgers/women/',
#  'https://www.sports-reference.com/cbb/schools/sacramento-state/women/',
#  'https://www.sports-reference.com/cbb/schools/sacred-heart/women/',
#  'https://www.sports-reference.com/cbb/schools/saint-francis-pa/women/',
#  'https://www.sports-reference.com/cbb/schools/saint-josephs/women/',
#  'https://www.sports-reference.com/cbb/schools/saint-louis/women/',
#  'https://www.sports-reference.com/cbb/schools/saint-marys-ca/women/',
#  'https://www.sports-reference.com/cbb/schools/saint-peters/women/',
#  'https://www.sports-reference.com/cbb/schools/sam-houston-state/women/',
#  'https://www.sports-reference.com/cbb/schools/samford/women/',
#  'https://www.sports-reference.com/cbb/schools/san-diego/women/',
#  'https://www.sports-reference.com/cbb/schools/san-diego-state/women/',
#  'https://www.sports-reference.com/cbb/schools/san-francisco/women/',
#  'https://www.sports-reference.com/cbb/schools/san-jose-state/women/',
#  'https://www.sports-reference.com/cbb/schools/santa-clara/women/',
#  'https://www.sports-reference.com/cbb/schools/savannah-state/women/',
#  'https://www.sports-reference.com/cbb/schools/seattle/women/',
#  'https://www.sports-reference.com/cbb/schools/seton-hall/women/',
#  'https://www.sports-reference.com/cbb/schools/siena/women/',
#  'https://www.sports-reference.com/cbb/schools/south-alabama/women/',
#  'https://www.sports-reference.com/cbb/schools/south-carolina/women/',
#  'https://www.sports-reference.com/cbb/schools/south-carolina-state/women/',
#  'https://www.sports-reference.com/cbb/schools/south-carolina-upstate/women/',
#  'https://www.sports-reference.com/cbb/schools/south-dakota/women/',
#  'https://www.sports-reference.com/cbb/schools/south-dakota-state/women/',
#  'https://www.sports-reference.com/cbb/schools/south-florida/women/',
#  'https://www.sports-reference.com/cbb/schools/southeast-missouri-state/women/',
#  'https://www.sports-reference.com/cbb/schools/southeastern-louisiana/women/',
#  'https://www.sports-reference.com/cbb/schools/southern/women/',
#  'https://www.sports-reference.com/cbb/schools/southern-california/women/',
#  'https://www.sports-reference.com/cbb/schools/southern-illinois/women/',
#  'https://www.sports-reference.com/cbb/schools/southern-illinois-edwardsville/women/',
#  'https://www.sports-reference.com/cbb/schools/southern-indiana/women/',
#  'https://www.sports-reference.com/cbb/schools/southern-methodist/women/',
#  'https://www.sports-reference.com/cbb/schools/southern-mississippi/women/',
#  'https://www.sports-reference.com/cbb/schools/southern-utah/women/',
#  'https://www.sports-reference.com/cbb/schools/st-bonaventure/women/',
#  'https://www.sports-reference.com/cbb/schools/st-francis-ny/women/',
#  'https://www.sports-reference.com/cbb/schools/st-johns-ny/women/',
#  'https://www.sports-reference.com/cbb/schools/st-thomas-mn/women/',
#  'https://www.sports-reference.com/cbb/schools/stanford/women/',
#  'https://www.sports-reference.com/cbb/schools/stephen-f-austin/women/',
#  'https://www.sports-reference.com/cbb/schools/stetson/women/',
#  'https://www.sports-reference.com/cbb/schools/stonehill/women/',
#  'https://www.sports-reference.com/cbb/schools/stony-brook/women/',
#  'https://www.sports-reference.com/cbb/schools/syracuse/women/',
#  'https://www.sports-reference.com/cbb/schools/tarleton-state/women/',
#  'https://www.sports-reference.com/cbb/schools/texas-christian/women/',
#  'https://www.sports-reference.com/cbb/schools/temple/women/',
#  'https://www.sports-reference.com/cbb/schools/tennessee/women/',
#  'https://www.sports-reference.com/cbb/schools/tennessee-state/women/',
#  'https://www.sports-reference.com/cbb/schools/tennessee-tech/women/',
#  'https://www.sports-reference.com/cbb/schools/tennessee-martin/women/',
#  'https://www.sports-reference.com/cbb/schools/texas/women/',
#  'https://www.sports-reference.com/cbb/schools/texas-am/women/',
#  'https://www.sports-reference.com/cbb/schools/texas-am-corpus-christi/women/',
#  'https://www.sports-reference.com/cbb/schools/texas-southern/women/',
#  'https://www.sports-reference.com/cbb/schools/texas-state/women/',
#  'https://www.sports-reference.com/cbb/schools/texas-tech/women/',
#  'https://www.sports-reference.com/cbb/schools/texas-pan-american/women/',
#  'https://www.sports-reference.com/cbb/schools/toledo/women/',
#  'https://www.sports-reference.com/cbb/schools/towson/women/',
#  'https://www.sports-reference.com/cbb/schools/troy/women/',
#  'https://www.sports-reference.com/cbb/schools/tulane/women/',
#  'https://www.sports-reference.com/cbb/schools/tulsa/women/',
#  'https://www.sports-reference.com/cbb/schools/alliant-international/women/',
#  'https://www.sports-reference.com/cbb/schools/alabama-birmingham/women/',
#  'https://www.sports-reference.com/cbb/schools/california-davis/women/',
#  'https://www.sports-reference.com/cbb/schools/california-irvine/women/',
#  'https://www.sports-reference.com/cbb/schools/california-riverside/women/',
#  'https://www.sports-reference.com/cbb/schools/california-san-diego/women/',
#  'https://www.sports-reference.com/cbb/schools/california-santa-barbara/women/',
#  'https://www.sports-reference.com/cbb/schools/central-florida/women/',
#  'https://www.sports-reference.com/cbb/schools/ucla/women/',
#  'https://www.sports-reference.com/cbb/schools/north-carolina-asheville/women/',
#  'https://www.sports-reference.com/cbb/schools/north-carolina-greensboro/women/',
#  'https://www.sports-reference.com/cbb/schools/north-carolina-wilmington/women/',
#  'https://www.sports-reference.com/cbb/schools/texas-arlington/women/',
#  'https://www.sports-reference.com/cbb/schools/utah/women/',
#  'https://www.sports-reference.com/cbb/schools/utah-state/women/',
#  'https://www.sports-reference.com/cbb/schools/dixie-state/women/',
#  'https://www.sports-reference.com/cbb/schools/utah-valley/women/',
#  'https://www.sports-reference.com/cbb/schools/texas-el-paso/women/',
#  'https://www.sports-reference.com/cbb/schools/texas-san-antonio/women/',
#  'https://www.sports-reference.com/cbb/schools/valparaiso/women/',
#  'https://www.sports-reference.com/cbb/schools/vanderbilt/women/',
#  'https://www.sports-reference.com/cbb/schools/vermont/women/',
#  'https://www.sports-reference.com/cbb/schools/villanova/women/',
#  'https://www.sports-reference.com/cbb/schools/virginia/women/',
#  'https://www.sports-reference.com/cbb/schools/virginia-commonwealth/women/',
#  'https://www.sports-reference.com/cbb/schools/virginia-tech/women/',
#  'https://www.sports-reference.com/cbb/schools/wagner/women/',
#  'https://www.sports-reference.com/cbb/schools/wake-forest/women/',
#  'https://www.sports-reference.com/cbb/schools/washington/women/',
#  'https://www.sports-reference.com/cbb/schools/washington-state/women/',
#  'https://www.sports-reference.com/cbb/schools/weber-state/women/',
#  'https://www.sports-reference.com/cbb/schools/west-chester/women/',
#  'https://www.sports-reference.com/cbb/schools/west-georgia/women/',
#  'https://www.sports-reference.com/cbb/schools/west-virginia/women/',
#  'https://www.sports-reference.com/cbb/schools/western-carolina/women/',
#  'https://www.sports-reference.com/cbb/schools/western-illinois/women/',
#  'https://www.sports-reference.com/cbb/schools/western-kentucky/women/',
#  'https://www.sports-reference.com/cbb/schools/western-michigan/women/',
#  'https://www.sports-reference.com/cbb/schools/wichita-state/women/',
#  'https://www.sports-reference.com/cbb/schools/william-mary/women/',
#  'https://www.sports-reference.com/cbb/schools/winthrop/women/',
#  'https://www.sports-reference.com/cbb/schools/wisconsin/women/',
#  'https://www.sports-reference.com/cbb/schools/wofford/women/',
#  'https://www.sports-reference.com/cbb/schools/wright-state/women/',
#  'https://www.sports-reference.com/cbb/schools/wyoming/women/',
#  'https://www.sports-reference.com/cbb/schools/xavier/women/',
#  'https://www.sports-reference.com/cbb/schools/yale/women/',
#  'https://www.sports-reference.com/cbb/schools/youngstown-state/women/']

# %%
import requests
from scrapy import Selector
import pandas as pd
import time

def get_2026_player_stats(school_url):
    # 1. Format the URL for the 2026 season
    target_url = f"{school_url.rstrip('/')}/2026.html"
    
    try:
        # 2. Get the page
        resp = requests.get(target_url, timeout=10)
        if resp.status_code != 200:
            print(f"Skipping {target_url}: Status {resp.status_code}")
            return []
        
        sel = Selector(text=resp.text)
        
        # 3. Target the specific table from your screenshot: id="players_per_game"
        # We look for rows inside the <tbody>
        rows = sel.css('table#players_per_game tbody tr')
        
        school_name = sel.css('h1 span[itemprop="name"]::text').get()
        school_data = []
        
        for row in rows:
            # Skip sub-headers or empty rows
            if row.css('.thead') or not row.css('td'):
                continue
            
            # 4. DYNAMIC COLUMN EXTRACTION
            # This creates a dictionary by looking at every cell's 'data-stat' attribute
            player_row = {'school': school_name}
            
            # Scrapy finds all <th> and <td> cells in this row
            for cell in row.css('th, td'):
                stat_name = cell.attrib.get('data-stat')
                if stat_name:
                    # Get the text inside the cell
                    player_row[stat_name] = cell.css('::text').get()
            
            school_data.append(player_row)
            
        return school_data

    except Exception as e:
        print(f"Error on {target_url}: {e}")
        return []

pd.DataFrame(get_2026_player_stats(links_list[0]))
# Out:
#    school ranker     name_display pos games games_started mp_per_g fg_per_g  \
# 0    None      1      Payton Hull   G    19            19     30.2      5.8
# 1    None      2   Meredith Mayes   C    16            16     28.4      6.3
# 2    None      3     Erin Woodson   G    19            19     31.6      5.0
# 3    None      4     Emma Troxell   F    18            18     28.6      3.2
# 4    None      5   Natalia Chavez   G    19             4     15.1      2.8
# 5    None      6    Breanna Davis   G    19            19     26.6      1.4
# 6    None      7     Jazmyn Stone   G    19             0     10.7      0.8
# 7    None      8    Riley Grohman   G    19             0     12.0      1.0
# 8    None      9  Molly Daugherty   G    17             0      7.6      0.7
# 9    None     10   Jordyn Coleman   C    15             0      5.7      0.9
# 10   None     11   Emma Daugherty   F    17             0      8.4      0.4
# 11   None     12       Bree Riley   G     8             0      5.4      0.5
# 12   None     13    Aimee Flippen   C    11             0      3.1      0.2
#
#    fga_per_g fg_pct  ... orb_per_g drb_per_g trb_per_g ast_per_g stl_per_g  \
# 0       14.4   .405  ...       0.9       3.1       4.0       2.9       2.7
# 1        9.3   .682  ...       3.3       4.6       7.9       1.6       2.5
# 2       10.6   .473  ...       1.7       4.3       5.9       2.2       1.9
# 3        8.4   .377  ...       1.8       4.3       6.1       1.2       1.7
# 4        5.7   .500  ...       0.9       1.2       2.2       0.6       0.7
# 5        4.2   .329  ...       0.4       1.6       2.0       3.5       1.1
# 6        2.6   .306  ...       0.4       0.6       1.0       1.6       0.5
# 7        3.1   .328  ...       0.4       0.8       1.2       0.7       0.6
# 8        2.1   .333  ...       0.2       0.5       0.6       0.5       0.2
# 9        1.8   .519  ...       0.6       1.1       1.7       0.2       0.1
# 10       1.1   .368  ...       0.4       1.2       1.6       0.2       0.5
# 11       1.5   .333  ...       0.5       0.3       0.8       0.9       0.6
# 12       0.5   .333  ...       0.1       0.8       0.9       0.2       0.2
#
#    blk_per_g tov_per_g pf_per_g pts_per_g awards
# 0        0.3       3.0      2.1      17.0   None
# 1        0.8       1.4      2.5      15.2   None
# 2        0.4       2.0      1.9      14.5   None
# 3        0.1       1.1      1.8       9.8   None
# 4        0.2       0.6      1.0       7.5   None
# 5        0.1       2.3      2.7       3.9   None
# 6        0.1       1.8      1.2       2.5   None
# 7        0.1       0.7      0.9       2.5   None
# 8        0.0       0.6      0.9       2.1   None
# 9        0.5       0.3      0.9       2.0   None
# 10       0.0       0.4      0.7       1.1   None
# 11       0.0       0.8      0.6       1.0   None
# 12       0.0       0.2      0.7       0.5   None
#
# [13 rows x 30 columns]

# %%
import requests
from scrapy import Selector
import pandas as pd
import time

def get_2026_stats_df(school_url):
    year = 2026
    season_val = f"{year-1}-{str(year)[-2:]}"
    
    # Extract school slug
    parts = [p for p in school_url.split('/') if p]
    school_slug = parts[-2] if parts[-1] == 'women' else parts[-1]
    
    target_url = f"{school_url.rstrip('/')}/{year}.html"
    
    try:
        resp = requests.get(target_url, timeout=10)
        if resp.status_code != 200:
            return pd.DataFrame()
        
        sel = Selector(text=resp.text)
        rows = sel.css('table#players_per_game tbody tr')
        
        all_rows = []
        for row in rows:
            if row.css('.thead') or not row.css('td'):
                continue
            
            # 1. Grab everything with original keys
            row_data = {cell.attrib['data-stat']: cell.css('::text').get() 
                        for cell in row.css('th, td') if 'data-stat' in cell.attrib}
            
            # 2. Add our custom metadata
            row_data['school'] = school_slug
            row_data['season'] = season_val
            all_rows.append(row_data)
        
        df = pd.DataFrame(all_rows)
        
        if not df.empty:
            # 3. Remove unwanted columns
            cols_to_drop = [c for c in ['ranker', 'awards'] if c in df.columns]
            df = df.drop(columns=cols_to_drop)
            
            # 4. Rename the name column
            # Check for 'name_display' first, then fallback to 'player'
            if 'name_display' in df.columns:
                df = df.rename(columns={'name_display': 'player_name'})
            elif 'player' in df.columns:
                df = df.rename(columns={'player': 'player_name'})
            
            # 5. Reorder: school, season, player_name, then everything else
            cols = ['school', 'season', 'player_name']
            # Get all other columns that aren't in our "start" list
            other_cols = [c for c in df.columns if c not in cols]
            df = df[cols + other_cols]

        return df

    except Exception as e:
        print(f"Error on {school_slug}: {e}")
        return pd.DataFrame()

get_2026_stats_df(links_list[0])
# Out:
#                school   season      player_name pos games games_started  \
# 0   abilene-christian  2025-26      Payton Hull   G    19            19
# 1   abilene-christian  2025-26   Meredith Mayes   C    16            16
# 2   abilene-christian  2025-26     Erin Woodson   G    19            19
# 3   abilene-christian  2025-26     Emma Troxell   F    18            18
# 4   abilene-christian  2025-26   Natalia Chavez   G    19             4
# 5   abilene-christian  2025-26    Breanna Davis   G    19            19
# 6   abilene-christian  2025-26     Jazmyn Stone   G    19             0
# 7   abilene-christian  2025-26    Riley Grohman   G    19             0
# 8   abilene-christian  2025-26  Molly Daugherty   G    17             0
# 9   abilene-christian  2025-26   Jordyn Coleman   C    15             0
# 10  abilene-christian  2025-26   Emma Daugherty   F    17             0
# 11  abilene-christian  2025-26       Bree Riley   G     8             0
# 12  abilene-christian  2025-26    Aimee Flippen   C    11             0
#
#    mp_per_g fg_per_g fga_per_g fg_pct  ... ft_pct orb_per_g drb_per_g  \
# 0      30.2      5.8      14.4   .405  ...   .813       0.9       3.1
# 1      28.4      6.3       9.3   .682  ...   .714       3.3       4.6
# 2      31.6      5.0      10.6   .473  ...   .694       1.7       4.3
# 3      28.6      3.2       8.4   .377  ...   .804       1.8       4.3
# 4      15.1      2.8       5.7   .500  ...  1.000       0.9       1.2
# 5      26.6      1.4       4.2   .329  ...   .591       0.4       1.6
# 6      10.7      0.8       2.6   .306  ...   .625       0.4       0.6
# 7      12.0      1.0       3.1   .328  ...  1.000       0.4       0.8
# 8       7.6      0.7       2.1   .333  ...   .600       0.2       0.5
# 9       5.7      0.9       1.8   .519  ...   .400       0.6       1.1
# 10      8.4      0.4       1.1   .368  ...   .625       0.4       1.2
# 11      5.4      0.5       1.5   .333  ...   None       0.5       0.3
# 12      3.1      0.2       0.5   .333  ...   .500       0.1       0.8
#
#    trb_per_g ast_per_g stl_per_g blk_per_g tov_per_g pf_per_g pts_per_g
# 0        4.0       2.9       2.7       0.3       3.0      2.1      17.0
# 1        7.9       1.6       2.5       0.8       1.4      2.5      15.2
# 2        5.9       2.2       1.9       0.4       2.0      1.9      14.5
# 3        6.1       1.2       1.7       0.1       1.1      1.8       9.8
# 4        2.2       0.6       0.7       0.2       0.6      1.0       7.5
# 5        2.0       3.5       1.1       0.1       2.3      2.7       3.9
# 6        1.0       1.6       0.5       0.1       1.8      1.2       2.5
# 7        1.2       0.7       0.6       0.1       0.7      0.9       2.5
# 8        0.6       0.5       0.2       0.0       0.6      0.9       2.1
# 9        1.7       0.2       0.1       0.5       0.3      0.9       2.0
# 10       1.6       0.2       0.5       0.0       0.4      0.7       1.1
# 11       0.8       0.9       0.6       0.0       0.8      0.6       1.0
# 12       0.9       0.2       0.2       0.0       0.2      0.7       0.5
#
# [13 rows x 29 columns]
