# %% [markdown]
# # Scrape NCAA Stats #

# %% [markdown]
# # TODO #
# * [ ] Check for api
# * [ ] Get api/html
# * [ ] Pull minute-by-minute box (including subs)
# * [ ] Stretch
#     * [ ] Get list of when each player is on the court
#     * [ ] Compute stats of sets of all sets of n players when they're on the court together ($n \in [2, 5]$)

# %%
import numpy as np
import pandas as pd
import polars as pl
import scrapy
import selenium as sl
from selenium import webdriver  
from selenium.webdriver.common.by import By  
import os
import requests 
from tqdm import tqdm

# %%
options = Options()
options.add_argument("--headless")
driver = webdriver.Firefox(options=options)
driver.get("https://www.on3.com/transfer-portal/wire/womens-basketball/2025/")
time.sleep(2)

# find all anchor tags
anchors = driver.find_elements(By.TAG_NAME, "a")
#get all hrefs with "box_score" in them
box_score_links = [a.get_attribute('href') for a in anchors if a.get_attribute('href') and "box_score" in a.get_attribute('href')]
driver.quit()

# %%
hrefs = [a.get_attribute('href') for a in anchors tribute(']
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/github/BSA-Basketball-W26/.venv/lib/python3.14/site-packages/urllib3/connection.py:204, in _new_conn(self)
#     202         self.auto_open = 0
# --> 204 def connect(self):
#     205     conn = self._new_conn()
#
# File ~/github/BSA-Basketball-W26/.venv/lib/python3.14/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# File ~/github/BSA-Basketball-W26/.venv/lib/python3.14/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
# ---> 73     af, socktype, proto, canonname, sa = res
#      74     sock = None
#
# ...
